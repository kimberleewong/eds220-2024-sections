# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/Colorado River Basin Water Conflict Table.csv'  )

# %% [markdown]
# ## 3. Preliminary data exploration

# %%
# Sets the display so you can see all the columns
pd.set_option("display.max_columns", None)

# %%
# look at top 5 rows
(df.head())
# Out:
#    Event  Search Source                                   Newspaper  \
# 0      1  USGS1-50.docx               The Durango Herald (Colorado)
# 1      2  USGS1-50.docx  Journal, The (Cortez, Dolores, Mancos, CO)
# 2      3  USGS1-50.docx                       The Salt Lake Tribune
# 3      4  USGS1-50.docx                   Casa Grande Dispatch (AZ)
# 4      5  USGS1-50.docx                  The Aspen Times (Colorado)
#
#                                        Article Title Duplicate Report Date  \
# 0  Tribes assert water rights on Colorado River B...     False    7-Apr-22
# 1  Native American tribes assert water rights on ...     False    7-Apr-22
# 2  'Very positive change.' New Utah law will be a...     False   17-Mar-22
# 3  Legislation would let an Arizona tribe lease C...     False   11-Dec-21
# 4  Historically excluded from Colorado River poli...     False   19-Dec-21
#
#    Report Year Event Date  Event Day  Event Month  Event Year  \
# ...

# %%
# look at last 5 rows
(df.tail())
# Out:
#      Event     Search Source                                   Newspaper  \
# 263    264  USGS301-350.docx               The Durango Herald (Colorado)
# 264    265  USGS301-350.docx  Rio Blanco Herald Times (Meeker, Colorado)
# 265    266  USGS301-350.docx                   Casa Grande Dispatch (AZ)
# 266    267  USGS301-350.docx                       The Salt Lake Tribune
# 267    268  USGS301-350.docx                   Casa Grande Dispatch (AZ)
#
#                                          Article Title Duplicate Report Date  \
# 263  Water officials consider action for worst case...     False    9-Jun-09
# 264        Rangely hosts Colorado River District event     False   21-Apr-22
# 265  California water district lawsuit threatens dr...     False   18-Apr-19
# 266  Scientists want to flush water past Glen Canyo...     False   13-Dec-07
# 267         Arizona plan could devastate Pinal farmers       NaN    2-Feb-19
#
# ...

# %%
# look at column types
(df.dtypes)
# Out:
# Event                                             int64
# Search Source                                    object
# Newspaper                                        object
# Article Title                                    object
# Duplicate                                        object
# Report Date                                      object
# Report Year                                     float64
# Event Date                                       object
# Event Day                                       float64
# Event Month                                     float64
# Event Year                                      float64
# Conflict Present                                 object
# Crisis Present                                   object
# Basin                                            object
# HUC6                                             object
# HUC2                                             object
# Place                                            object
# ...

# %%
# look at unique basins
(df['Basin'].unique())
# Out:
# array(['Upper San Juan', 'Great Salt Lake', 'Lower Colorado',
#        'Entire Lower Colorado Basin', 'Entire Colorado River Basin',
#        'Lower Green', 'South Platte', 'Lower Colorado-Lake Mead',
#        'Entire Upper Colorado Basin', 'Middle Gila',
#        'Upper Colorado-Dirty Devil', 'Colorado Headwaters', nan,
#        'Little Colorado', 'White-Yampa', 'Lower Gila-Agua Fria',
#        'Upper Green', 'Santa Cruz', 'Salt', 'Salton Sea',
#        'Upper San Juan, Salton Sea, Salt, Rio De La Concepcion, Lower San Juan, Upper Colorado-Dirty Devil, Bill Williams, Middle Gila, Santa Cruz, Verde, Lower Gila, San Pedro-Willcox, Rio Sonoyta, Lower Colorado, Little Colorado, Lower Colorado-Lake Mead, Upper Gila, Rio De Bavispe, Lower Gila-Agua Fria ',
#        'Upper Colorado-Dirty Devil, Upper San Juan',
#        'Upper Colorado-Dirty Devil, Lower San Juan, Little Colorado, Lower Colorado-Lake Mead',
#        'Salt, Lower Colorado', 'Upper Gila', 'Lower San Juan'],
# ...

# %% [markdown]
# ## 5. String Accessor

# %%
# Example series
s = pd.Series(['California; Nevada', 'Arizona', np.nan, 'Nevada; Utah'])
s
# Out:
# 0    California; Nevada
# 1               Arizona
# 2                   NaN
# 3          Nevada; Utah
# dtype: object

# %%
# str accessor (doesn't do anything by itself)
s.str

# %%
# Use str accessor with additional methods to perform string operations
# .split splits strings by ';' and expands output into separate columns
s.str.split(';', expand=True)
# Out:
#             0        1
# 0  California   Nevada
# 1     Arizona     None
# 2         NaN      NaN
# 3      Nevada     Utah

# %%
# Use stack() method to flatten the data frame into a series
# default is to drop NAs and None from result
check = (s.str.split(';', expand=True).stack())
print(check)
# Out:
# 0  0    California
#    1        Nevada
# 1  0       Arizona
# 3  0        Nevada
#    1          Utah
# dtype: object

# %%
df["State"].unique()
# Out:
# array(['CO', 'UT', nan, 'AZ', 'OH; UT', 'AZ; CO; NM; UT', 'CA', 'AZ; UT',
#        'AZ; NV', 'CO; UT; WY; NM', 'AZ; CA', 'UT; AZ', 'CO; WY', 'NV; AZ',
#        'CO; AZ', 'AZ; CA; CO; NV; NM; UT; WY', 'AZ; CA; NV', 'NV', 'NM',
#        'UT; CO; WY', 'CA; NV; AZ', 'AZ; NM', 'WY; UT; CO', 'TX'],
#       dtype=object)

# %%
# Out:
#      Event     Search Source                                   Newspaper  \
# 0        1     USGS1-50.docx               The Durango Herald (Colorado)
# 1        2     USGS1-50.docx  Journal, The (Cortez, Dolores, Mancos, CO)
# 2        3     USGS1-50.docx                       The Salt Lake Tribune
# 3        4     USGS1-50.docx                   Casa Grande Dispatch (AZ)
# 4        5     USGS1-50.docx                  The Aspen Times (Colorado)
# ..     ...               ...                                         ...
# 263    264  USGS301-350.docx               The Durango Herald (Colorado)
# 264    265  USGS301-350.docx  Rio Blanco Herald Times (Meeker, Colorado)
# 265    266  USGS301-350.docx                   Casa Grande Dispatch (AZ)
# 266    267  USGS301-350.docx                       The Salt Lake Tribune
# 267    268  USGS301-350.docx                   Casa Grande Dispatch (AZ)
#
#                                          Article Title Duplicate Report Date  \
# ...

# %%
# Subset data where there are water conflicts

# Use .str and .split to split the rows in which there are two states present in their state code

# Stack to get rid of the NAs 

# Use .unique to get the unique states for where there are water conflicts

# %% [markdown]
# ## 8. Exploratory Wrangling

# %%
df2 = df[df['Conflict Present'] == 'Y']
(df2)
df2 = df2['State'].str.split(';', expand=True).stack().unique()
df2
# Out:
# array(['CO', 'AZ', 'OH', ' UT', 'UT', 'CA', ' NV', ' WY', ' NM', ' CA',
#        'NV', ' AZ', ' CO', 'NM', 'WY'], dtype=object)

# %%
df['State'].str.split(';', expand=True).stack().str.strip().value_counts()
# Out:
# AZ    87
# CO    45
# UT    40
# NV    19
# CA    16
# NM    13
# WY     8
# OH     1
# TX     1
# dtype: int64

# %%
df[df['Conflict Present']== "Y"].loc[:,'State'].str.split(';', expand=True).stack().str.strip().value_counts()
# Out:
# AZ    45
# UT    29
# CO    22
# NV    12
# NM    10
# CA     7
# WY     6
# OH     1
# dtype: int64

# %%
df[df['Conflict Present']== "Y"]
# Out:
#      Event     Search Source                                   Newspaper  \
# 0        1     USGS1-50.docx               The Durango Herald (Colorado)
# 1        2     USGS1-50.docx  Journal, The (Cortez, Dolores, Mancos, CO)
# 4        5     USGS1-50.docx                  The Aspen Times (Colorado)
# 5        6     USGS1-50.docx              The Arizona Republic (Phoenix)
# 7        8     USGS1-50.docx         Navajo Times (Window Rock, Arizona)
# ..     ...               ...                                         ...
# 257    258  USGS301-350.docx              The Arizona Republic (Phoenix)
# 258    259  USGS301-350.docx                       The Salt Lake Tribune
# 260    261  USGS301-350.docx         Farmington Daily Times (New Mexico)
# 262    263  USGS301-350.docx              Associated Press State & Local
# 265    266  USGS301-350.docx                   Casa Grande Dispatch (AZ)
#
#                                          Article Title Duplicate Report Date  \
# ...

# %%
# Out:
# Object `df()` not found.
